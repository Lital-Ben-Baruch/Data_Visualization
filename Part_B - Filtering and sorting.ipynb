# %% [markdown]
# <a href="https://colab.research.google.com/github/Lital-Ben-Baruch/Data_Visualization/blob/main/Part_B%20-%20Filtering%20and%20sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part B - Filtering and sorting

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 3. Assign it to a variable called df_occupation.

# %%
df_army = pd.read_csv('/content/drive/My Drive/Summaries _ML_AI_CV/data_sets/pandas/army.csv', sep = ',')

# %% [markdown]
# ### Step 4. See the veterans columns by index (Sort df by labels along veterans column.)

# %% [markdown]
# #### Option A

# %%
df_army.veterans
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %% [markdown]
# .sort_index Returns a new DataFrame sorted by label if inplace argument is False, otherwise updates the original DataFrame and returns None.

# %% [markdown]
# #### Option B

# %%
df_army.veterans.sort_index()
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 5. See the veterans & deaths columns by index (Sort df by labels along veterans column.)

# %% [markdown]
# #### Option A

# %%
df_army[['veterans', 'deaths']]
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %% [markdown]
# #### Option B

# %%
df_army[['veterans', 'deaths']].sort_index()
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %% [markdown]
# ### Step 6. Assign the 'death', 'size' and 'deserters' columns for the states of Maine and Alaska to a DataFrame called 'new_df'.

# %% [markdown]
# #### Option A

# %%
new_df_A = df_army.loc[df_army.origin.isin(['Maine', 'Alaska']), ['origin','deaths','size','deserters' ]]
new_df_A
# Out:
#    origin  deaths  size  deserters
# 4   Maine      43  1592          3
# 6  Alaska     523   987         24

# %% [markdown]
# #### Option B

# %%
condition=df_army.origin.isin(['Maine', 'Alaska'])
new_df_B = df_army[condition][['origin','deaths','size','deserters' ]]
new_df_B
# Out:
#    origin  deaths  size  deserters
# 4   Maine      43  1592          3
# 6  Alaska     523   987         24

# %% [markdown]
# ### Step 7. Choose the third through seventh lines and present only the third through sixth columns.

# %% [markdown]
# The desired region for this step is displayed in a green squer.

# %% [markdown]
# ![pic2.png](data:image/png;base64,...)

# %% [markdown]
# Let's take a look at each line and column's index:
# * The third line index is 2.
# * The seventh line index is 6.
# * The third column index is 2.
# * the sixth column index is 5.
#
# .iloc[] is an integer position-based function that can be used with a boolean array (from 0 to **length-1** * of the axis).
# * therfore, the length-1 value will be 6 and not 5

# %%
df_army.iloc[2:7,2:6]
# Out:
#   company  deaths  battles  size
# 2     2nd      25        2  1099
# 3     2nd     616        2  1400
# 4     1st      43        4  1592
# 5     1st     234        7  1006
# 6     2nd     523        8   987

# %% [markdown]
# ### Step 8. Choose the blue squer - all data except the first three lines

# %%
df_army.iloc[ 3 : ,: ]
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 4        Maine    Dragoons     1st      43        4  1592        73
# 5         Iowa    Dragoons     1st     234        7  1006        37
# 6       Alaska    Dragoons     2nd     523        8   987       949
# 7   Washington    Dragoons     2nd      62        3   849        48
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 3           3        1          2
# 4           2        0          3
# 5           1        1          4
# 6           2        0         24
# 7           3        1         31
# 8           2        0          2
# 9           1        0          3
# ...

# %% [markdown]
# ### Step 9. Choose the yellow squer - first 4 lines and first free columns

# %%
df_army.iloc[ :4 ,:3]
# Out:
#        origin    regiment company
# 0     Arizona  Nighthawks     1st
# 1  California  Nighthawks     1st
# 2       Texas  Nighthawks     2nd
# 3     Florida  Nighthawks     2nd

# %% [markdown]
# ### Step 10. Choose the following squer -

# %% [markdown]
# ![pic3.png](data:image/png;base64,...)

# %%
df_army.iloc[:,2:7]
# Out:
#    company  deaths  battles  size  veterans
# 0      1st     523        5  1045         1
# 1      1st      52       42   957         5
# 2      2nd      25        2  1099        62
# 3      2nd     616        2  1400        26
# 4      1st      43        4  1592        73
# 5      1st     234        7  1006        37
# 6      2nd     523        8   987       949
# 7      2nd      62        3   849        48
# 8      1st      62        4   973        48
# 9      1st      73        7  1005       435
# 10     2nd      37        8  1099        63
# 11     2nd      35        9  1523       345

# %% [markdown]
# ### Step 11. Choose the lines containing a death value greater than 50

# %%
df_army[df_army.deaths>50]
# Out:
#        origin    regiment company  deaths  battles  size  veterans  readiness  \
# 0     Arizona  Nighthawks     1st     523        5  1045         1          1
# 1  California  Nighthawks     1st      52       42   957         5          2
# 3     Florida  Nighthawks     2nd     616        2  1400        26          3
# 5        Iowa    Dragoons     1st     234        7  1006        37          1
# 6      Alaska    Dragoons     2nd     523        8   987       949          2
# 7  Washington    Dragoons     2nd      62        3   849        48          3
# 8      Oregon      Scouts     1st      62        4   973        48          2
# 9     Wyoming      Scouts     1st      73        7  1005       435          1
#
#    armored  deserters
# 0        1          4
# 1        0         24
# 3        1          2
# 5        1          4
# 6        0         24
# 7        1         31
# 8        0          2
# 9        0          3

# %% [markdown]
# ### Step 12. Choose the lines containing a death value greater than 500 ***or*** smaller than 50

# %%
condition_1 = df_army.deaths<50
condition_2 = df_army.deaths>500
df_army[condition_1 | condition_2]
# Out:
#       origin    regiment company  deaths  battles  size  veterans  readiness  \
# 0    Arizona  Nighthawks     1st     523        5  1045         1          1
# 2      Texas  Nighthawks     2nd      25        2  1099        62          3
# 3    Florida  Nighthawks     2nd     616        2  1400        26          3
# 4      Maine    Dragoons     1st      43        4  1592        73          2
# 6     Alaska    Dragoons     2nd     523        8   987       949          2
# 10  Louisana      Scouts     2nd      37        8  1099        63          2
# 11   Georgia      Scouts     2nd      35        9  1523       345          3
#
#     armored  deserters
# 0         1          4
# 2         1         31
# 3         1          2
# 4         0          3
# 6         0         24
# 10        1          2
# 11        1          3

# %% [markdown]
# ### Step 13. Choose the lines containing a regiment value different than Dragoons

# %% [markdown]
# #### Option A

# %%
condition3=df_army.regiment !='Dragoons'
df_army[condition3]
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 0      Arizona  Nighthawks     1st     523        5  1045         1
# 1   California  Nighthawks     1st      52       42   957         5
# 2        Texas  Nighthawks     2nd      25        2  1099        62
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 0           1        1          4
# 1           2        0         24
# 2           3        1         31
# 3           3        1          2
# 8           2        0          2
# 9           1        0          3
# 10          2        1          2
# 11          3        1          3

# %% [markdown]
# #### Option B

# %%
condition_3B= ~df_army["regiment"].str.contains('Dragoons')
df_army[condition_3B]
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 0      Arizona  Nighthawks     1st     523        5  1045         1
# 1   California  Nighthawks     1st      52       42   957         5
# 2        Texas  Nighthawks     2nd      25        2  1099        62
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 0           1        1          4
# 1           2        0         24
# 2           3        1         31
# 3           3        1          2
# 8           2        0          2
# 9           1        0          3
# 10          2        1          2
# 11          3        1          3

# %% [markdown]
# ### Step 14. Choose the lines where the index is Arizona or Texas

# %%
condition4=df_army.origin =='Arizona'
condition5=df_army.origin =='Texas'
df_army[condition4|condition5]
# Out:
#     origin    regiment company  deaths  battles  size  veterans  readiness  \
# 0  Arizona  Nighthawks     1st     523        5  1045         1          1
# 2    Texas  Nighthawks     2nd      25        2  1099        62          3
#
#    armored  deserters
# 0        1          4
# 2        1         31

# %% [markdown]
# ### Step 15. Choose the third line for deaths column

# %%
df_army.head()
# Out:
#        origin    regiment company  deaths  battles  size  veterans  readiness  \
# 0     Arizona  Nighthawks     1st     523        5  1045         1          1
# 1  California  Nighthawks     1st      52       42   957         5          2
# 2       Texas  Nighthawks     2nd      25        2  1099        62          3
# 3     Florida  Nighthawks     2nd     616        2  1400        26          3
# 4       Maine    Dragoons     1st      43        4  1592        73          2
#
#    armored  deserters
# 0        1          4
# 1        0         24
# 2        1         31
# 3        1          2
# 4        0          3

# %% [markdown]
# The answer should be 25.

# %%
a = df_army.deaths[2]
a
# Out:
# 25

# %%
b = df_army.deaths.iloc[2]
b
# Out:
# 25

# %% [markdown]
# .at is similar to loc, in that both provide label-based lookups. Use at if you only need to get or set a single value in a DataFrame or Series.

# %%
c = df_army.at[2,'deaths']
c
# Out:
# 25
